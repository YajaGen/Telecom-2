# %%
import pandas as pd

# Cargar el archivo CSV tratado
df = pd.read_csv("telecom_tratado.csv")

# Ver las primeras filas
df.head()
# Out:
#    customerid  churn  gender  seniorcitizen  partner  dependents  tenure  \
# 0  0002-ORFBO      0  Female              0        1           1       9
# 1  0003-MKNFE      0    Male              0        0           0       9
# 2  0004-TLHLJ      1    Male              0        0           0       4
# 3  0011-IGKFF      1    Male              1        1           0      13
# 4  0013-EXCHZ      1  Female              1        1           0       3
#
#    phoneservice  multiplelines internetservice  ...  deviceprotection  \
# 0             1              0             DSL  ...                 0
# 1             1              1             DSL  ...                 0
# 2             1              0     Fiber optic  ...                 1
# 3             1              0     Fiber optic  ...                 1
# 4             1              0     Fiber optic  ...                 0
#
#    techsupport  streamingtv  streamingmovies        contract  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerid        7032 non-null   object
#  1   churn             7032 non-null   int64
#  2   gender            7032 non-null   object
#  3   seniorcitizen     7032 non-null   int64
#  4   partner           7032 non-null   int64
#  5   dependents        7032 non-null   int64
#  6   tenure            7032 non-null   int64
#  7   phoneservice      7032 non-null   int64
#  8   multiplelines     7032 non-null   int64
#  9   internetservice   7032 non-null   object
#  10  onlinesecurity    7032 non-null   int64
#  11  onlinebackup      7032 non-null   int64
#  12  deviceprotection  7032 non-null   int64
#  13  techsupport       7032 non-null   int64
#  14  streamingtv       7032 non-null   int64
#  15  streamingmovies   7032 non-null   int64
# ...

# %%
df.drop(columns=['customerid'], inplace=True)

# %%
# Aplicar One-Hot Encoding solo a las columnas categóricas
df_encoded = pd.get_dummies(df, columns=['gender', 'internetservice', 'contract', 'paymentmethod'], drop_first=True)

# %%
# Ver proporción de cancelación
df_encoded['churn'].value_counts(normalize=True)
# Out:
# churn
# 0    0.734215
# 1    0.265785
# Name: proportion, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X = df_encoded.drop('churn', axis=1)
y = df_encoded['churn']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %% [markdown]
# # Correlación y selección de variables

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filtrar solo columnas numéricas
num_df = df_encoded.select_dtypes(include=['int64', 'float64'])

# Matriz de correlación
plt.figure(figsize=(12, 8))
sns.heatmap(num_df.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Matriz de Correlación")
plt.show()

# Ver correlación específica con churn
correlation_with_churn = num_df.corr()['churn'].sort_values(ascending=False)
print(correlation_with_churn)
# Out:
# churn               1.000000
# Cuentas_Diarias     0.192858
# charges.monthly     0.192858
# paperlessbilling    0.191454
# seniorcitizen       0.150541
# streamingtv         0.063254
# streamingmovies     0.060860
# multiplelines       0.040033
# phoneservice        0.011691
# deviceprotection   -0.066193
# onlinebackup       -0.082307
# partner            -0.149982
# dependents         -0.163128
# techsupport        -0.164716
# onlinesecurity     -0.171270
# charges.total      -0.199484
# tenure             -0.354049
# Name: churn, dtype: float64

# %% [markdown]
# # Analisis dirigido

# %%
# A. Contrato vs Cancelación (Contract × Churn)


sns.countplot(data=df, x='contract', hue='churn')
plt.title("Cancelación por Tipo de Contrato")
plt.xlabel("Tipo de Contrato")
plt.ylabel("Cantidad")
plt.show()

# %%
# B. Gasto total vs Cancelación (Total Charges × Churn)

sns.boxplot(data=df, x='churn', y='charges.total')
plt.title("Gasto Total vs Cancelación")
plt.xlabel("Churn")
plt.ylabel("Gasto Total")
plt.show()

# %% [markdown]
# # Modelo Predictivo

# %%
#Separación de Datos (80/20)

from sklearn.model_selection import train_test_split

# X e y ya están definidos
X = df_encoded.drop('churn', axis=1)
y = df_encoded['churn']

# División estratificada para mantener proporción
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %%
#A. Modelo 1: Regresión Logística (requiere normalización)

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# Normalización
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Entrenamiento
logreg = LogisticRegression(max_iter=1000, random_state=42)
logreg.fit(X_train_scaled, y_train)

# Predicción
y_pred_log = logreg.predict(X_test_scaled)

# Evaluación
print("🔹 Regresión Logística")
print(confusion_matrix(y_test, y_pred_log))
print(classification_report(y_test, y_pred_log))
# Out:
# 🔹 Regresión Logística
# [[929 104]
#  [176 198]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87      1033
#            1       0.66      0.53      0.59       374
#
#     accuracy                           0.80      1407
#    macro avg       0.75      0.71      0.73      1407
# weighted avg       0.79      0.80      0.79      1407

# %%
#B. Modelo 2: Random Forest (no necesita normalización)

from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)

print("🔹 Random Forest")
print(confusion_matrix(y_test, y_pred_rf))
print(classification_report(y_test, y_pred_rf))
# Out:
# 🔹 Random Forest
# [[933 100]
#  [191 183]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.87      1033
#            1       0.65      0.49      0.56       374
#
#     accuracy                           0.79      1407
#    macro avg       0.74      0.70      0.71      1407
# weighted avg       0.78      0.79      0.78      1407

# %% [markdown]
# ✅ Análisis de la Importancia de las Variables
#
#
# 🔹 1. Regresión Logística
# Usamos los coeficientes para identificar qué variables aumentan o disminuyen la probabilidad de cancelación (churn):
#
# python
# Copy
# Edit
# import pandas as pd
#
# # Obtener coeficientes
# coeficientes = pd.DataFrame({
#     'Variable': X_train.columns,
#     'Coeficiente': modelo_log.coef_[0]
# }).sort_values(by='Coeficiente', ascending=False)
#
# display(coeficientes.head(10))
# Coeficientes positivos → Aumentan la probabilidad de churn.
#
# Coeficientes negativos → Disminuyen la probabilidad de churn.
#
# ✅ Variables más influyentes en churn:
#
# contract_Two year (negativo)
#
# tenure (negativo)
#
# charges.total (negativo)
#
# contract_Month-to-month (positivo)
#
# paymentmethod_Electronic check (positivo)
#
# 🔹 2. Random Forest
# python
# Copy
# Edit
# importances = pd.DataFrame({
#     'Variable': X_train.columns,
#     'Importancia': modelo_rf.feature_importances_
# }).sort_values(by='Importancia', ascending=False)
#
# display(importances.head(10))
# ✅ Variables más importantes según Random Forest:
#
# tenure
#
# charges.total
#
# charges.monthly
#
# contract_Month-to-month
#
# paymentmethod_Electronic check
#
# Coincide con los hallazgos de la regresión, lo que refuerza su validez.
#
# 📌 Conclusiones Finales
# 🎯 Factores que más influyen en la cancelación:
# Tipo de contrato:
# Los clientes con contrato mensual tienen mayor probabilidad de cancelar.
# Contratos de dos años tienen fuerte efecto protector.
#
# Antigüedad del cliente (tenure):
# A menor tiempo con la empresa, mayor riesgo de churn.
# Es un fuerte predictor.
#
# Método de pago:
# El uso de Electronic check se asocia con mayor churn.
#
# Gasto mensual alto también contribuye al abandono, aunque no tan fuertemente como las anteriores.
#
# 💡 Estrategias de Retención Sugeridas
# Fidelización temprana: Diseñar campañas dirigidas a clientes nuevos (primeros 6 meses), que es cuando más se cancelan.
#
# Incentivos para contratos anuales o bianuales: Ofrecer descuentos o beneficios para quienes cambien su contrato a uno de más duración.
#
# Mejorar experiencia de pago: Analizar si los clientes que usan Electronic check están teniendo problemas en su proceso de pago o son de perfil de riesgo.
#
# Alertas tempranas: Implementar sistemas de alerta que detecten bajo tenure + contrato mensual + pago electrónico para tomar acción proactiva.
